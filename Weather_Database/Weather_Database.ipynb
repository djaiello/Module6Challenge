# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 767

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = url = "http://api.openweathermap.org/data/2.5/weather?"
url = url + "units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc,
                          "Country": city_country})
                         
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saint anthony
# Processing Record 2 of Set 1 | coahuayana
# Processing Record 3 of Set 1 | lagunas
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | pevek
# Processing Record 6 of Set 1 | libas
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | pontianak
# Processing Record 13 of Set 1 | madang
# Processing Record 14 of Set 1 | bethel
# Processing Record 15 of Set 1 | yellowknife
# Processing Record 16 of Set 1 | gamba
# Processing Record 17 of Set 1 | port lincoln
# Processing Record 18 of Set 1 | mogadishu
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | tezu
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | mabaruma
# Processing Record 23 of Set 1 | colac
# Processing Record 24 of Set 1 | tanta
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | vao
# Processing Record 27 of Set 1 | aklavik
# Processing Record 28 of Set 1 | new richmond
# Processing Record 29 of Set 1 | sao filipe
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | bredasdorp
# Processing Record 32 of Set 1 | hilo
# Processing Record 33 of Set 1 | mangile
# City not found. Skipping...
# Processing Record 34 of Set 1 | oistins
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | nanortalik
# Processing Record 37 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 38 of Set 1 | caravelas
# Processing Record 39 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 1 | butaritari
# Processing Record 41 of Set 1 | mahon
# Processing Record 42 of Set 1 | kapaa
# Processing Record 43 of Set 1 | airai
# Processing Record 44 of Set 1 | corinto
# Processing Record 45 of Set 1 | valdivia
# Processing Record 46 of Set 1 | mar del plata
# Processing Record 47 of Set 1 | carnarvon
# Processing Record 48 of Set 1 | kidal
# Processing Record 49 of Set 1 | karratha
# Processing Record 50 of Set 1 | jati
# Processing Record 1 of Set 2 | qaanaaq
# Processing Record 2 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 2 | bundaberg
# Processing Record 4 of Set 2 | shimoda
# Processing Record 5 of Set 2 | kijang
# Processing Record 6 of Set 2 | bandarbeyla
# Processing Record 7 of Set 2 | muros
# Processing Record 8 of Set 2 | port shepstone
# Processing Record 9 of Set 2 | bahia blanca
# Processing Record 10 of Set 2 | orje
# Processing Record 11 of Set 2 | aguimes
# Processing Record 12 of Set 2 | castro
# Processing Record 13 of Set 2 | kizlyar
# Processing Record 14 of Set 2 | bonavista
# Processing Record 15 of Set 2 | henties bay
# Processing Record 16 of Set 2 | los llanos de aridane
# Processing Record 17 of Set 2 | luangwa
# Processing Record 18 of Set 2 | baykit
# Processing Record 19 of Set 2 | port elizabeth
# Processing Record 20 of Set 2 | whitehorse
# Processing Record 21 of Set 2 | san patricio
# Processing Record 22 of Set 2 | bavleny
# Processing Record 23 of Set 2 | nova gradiska
# Processing Record 24 of Set 2 | leningradskiy
# Processing Record 25 of Set 2 | singapore
# Processing Record 26 of Set 2 | hilton head island
# Processing Record 27 of Set 2 | thongwa
# Processing Record 28 of Set 2 | mount isa
# Processing Record 29 of Set 2 | awjilah
# Processing Record 30 of Set 2 | klamath falls
# Processing Record 31 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 2 | turayf
# Processing Record 33 of Set 2 | torbay
# Processing Record 34 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 2 | iralaya
# Processing Record 36 of Set 2 | cidreira
# Processing Record 37 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 2 | roma
# Processing Record 39 of Set 2 | ribeira grande
# Processing Record 40 of Set 2 | tuktoyaktuk
# Processing Record 41 of Set 2 | salisbury
# Processing Record 42 of Set 2 | campbell river
# Processing Record 43 of Set 2 | harlingen
# Processing Record 44 of Set 2 | mahebourg
# Processing Record 45 of Set 2 | hobart
# Processing Record 46 of Set 2 | morant bay
# Processing Record 47 of Set 2 | te anau
# Processing Record 48 of Set 2 | longyearbyen
# Processing Record 49 of Set 2 | vaitape
# Processing Record 50 of Set 2 | kavieng
# Processing Record 1 of Set 3 | barrow
# Processing Record 2 of Set 3 | port alfred
# Processing Record 3 of Set 3 | avarua
# Processing Record 4 of Set 3 | san carlos de bariloche
# Processing Record 5 of Set 3 | lompoc
# Processing Record 6 of Set 3 | nikolskoye
# Processing Record 7 of Set 3 | sitka
# Processing Record 8 of Set 3 | belogradcik
# City not found. Skipping...
# Processing Record 9 of Set 3 | saskylakh
# Processing Record 10 of Set 3 | canutama
# Processing Record 11 of Set 3 | setermoen
# Processing Record 12 of Set 3 | bacuit
# City not found. Skipping...
# Processing Record 13 of Set 3 | taganak
# Processing Record 14 of Set 3 | verkhnevilyuysk
# Processing Record 15 of Set 3 | hermanus
# Processing Record 16 of Set 3 | atuona
# Processing Record 17 of Set 3 | korla
# Processing Record 18 of Set 3 | karpuninskiy
# City not found. Skipping...
# Processing Record 19 of Set 3 | nam tha
# City not found. Skipping...
# Processing Record 20 of Set 3 | ikom
# Processing Record 21 of Set 3 | ixtapa
# Processing Record 22 of Set 3 | maragogi
# Processing Record 23 of Set 3 | naftah
# City not found. Skipping...
# Processing Record 24 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 3 | ponta do sol
# Processing Record 26 of Set 3 | milingimbi
# City not found. Skipping...
# Processing Record 27 of Set 3 | japura
# Processing Record 28 of Set 3 | saint-philippe
# Processing Record 29 of Set 3 | kutum
# Processing Record 30 of Set 3 | new norfolk
# Processing Record 31 of Set 3 | cayenne
# Processing Record 32 of Set 3 | tasiilaq
# Processing Record 33 of Set 3 | bichena
# Processing Record 34 of Set 3 | cururupu
# Processing Record 35 of Set 3 | keti bandar
# Processing Record 36 of Set 3 | iqaluit
# Processing Record 37 of Set 3 | pechenga
# Processing Record 38 of Set 3 | murwara
# Processing Record 39 of Set 3 | sedalia
# Processing Record 40 of Set 3 | bud
# Processing Record 41 of Set 3 | straumen
# Processing Record 42 of Set 3 | victoria
# Processing Record 43 of Set 3 | bijie
# Processing Record 44 of Set 3 | merauke
# Processing Record 45 of Set 3 | tignere
# Processing Record 46 of Set 3 | mattru
# Processing Record 47 of Set 3 | ewa beach
# Processing Record 48 of Set 3 | lalsot
# Processing Record 49 of Set 3 | georgetown
# Processing Record 50 of Set 3 | taoudenni
# Processing Record 1 of Set 4 | tiksi
# Processing Record 2 of Set 4 | elat
# Processing Record 3 of Set 4 | arlit
# Processing Record 4 of Set 4 | khatanga
# Processing Record 5 of Set 4 | dombarovskiy
# Processing Record 6 of Set 4 | mangan
# Processing Record 7 of Set 4 | codrington
# Processing Record 8 of Set 4 | sorland
# Processing Record 9 of Set 4 | east london
# Processing Record 10 of Set 4 | diego de almagro
# Processing Record 11 of Set 4 | maniitsoq
# Processing Record 12 of Set 4 | vestmannaeyjar
# Processing Record 13 of Set 4 | arraial do cabo
# Processing Record 14 of Set 4 | klimovo
# Processing Record 15 of Set 4 | hambantota
# Processing Record 16 of Set 4 | esperance
# Processing Record 17 of Set 4 | upernavik
# Processing Record 18 of Set 4 | boueni
# Processing Record 19 of Set 4 | faanui
# Processing Record 20 of Set 4 | puerto ayora
# Processing Record 21 of Set 4 | pavlohrad
# Processing Record 22 of Set 4 | katherine
# Processing Record 23 of Set 4 | saint-augustin
# Processing Record 24 of Set 4 | langsa
# Processing Record 25 of Set 4 | montoro
# Processing Record 26 of Set 4 | clyde river
# Processing Record 27 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 4 | toktogul
# Processing Record 29 of Set 4 | raudeberg
# Processing Record 30 of Set 4 | kindu
# Processing Record 31 of Set 4 | rongcheng
# Processing Record 32 of Set 4 | cabedelo
# Processing Record 33 of Set 4 | vila
# Processing Record 34 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 4 | thompson
# Processing Record 36 of Set 4 | winsum
# Processing Record 37 of Set 4 | pangnirtung
# Processing Record 38 of Set 4 | artyshta
# Processing Record 39 of Set 4 | oktyabrskiy
# Processing Record 40 of Set 4 | pacific grove
# Processing Record 41 of Set 4 | ulladulla
# Processing Record 42 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 43 of Set 4 | yumen
# Processing Record 44 of Set 4 | kununurra
# Processing Record 45 of Set 4 | roebourne
# Processing Record 46 of Set 4 | am timan
# Processing Record 47 of Set 4 | bengkulu
# Processing Record 48 of Set 4 | isangel
# Processing Record 49 of Set 4 | souillac
# Processing Record 50 of Set 4 | pedasi
# Processing Record 1 of Set 5 | amos
# Processing Record 2 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 5 | vardo
# Processing Record 4 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 5 | adre
# Processing Record 6 of Set 5 | kroya
# Processing Record 7 of Set 5 | fagernes
# Processing Record 8 of Set 5 | asau
# Processing Record 9 of Set 5 | nieuw nickerie
# Processing Record 10 of Set 5 | hithadhoo
# Processing Record 11 of Set 5 | lebu
# Processing Record 12 of Set 5 | saint george
# Processing Record 13 of Set 5 | provideniya
# Processing Record 14 of Set 5 | lagoa
# Processing Record 15 of Set 5 | dingle
# Processing Record 16 of Set 5 | birin
# Processing Record 17 of Set 5 | skreia
# Processing Record 18 of Set 5 | roald
# Processing Record 19 of Set 5 | champerico
# Processing Record 20 of Set 5 | salalah
# Processing Record 21 of Set 5 | hasaki
# Processing Record 22 of Set 5 | hastings
# Processing Record 23 of Set 5 | coihaique
# Processing Record 24 of Set 5 | dikson
# Processing Record 25 of Set 5 | moose factory
# Processing Record 26 of Set 5 | suluq
# Processing Record 27 of Set 5 | weligama
# Processing Record 28 of Set 5 | kaitangata
# Processing Record 29 of Set 5 | adolfo lopez mateos
# Processing Record 30 of Set 5 | saint simons
# Processing Record 31 of Set 5 | kodiak
# Processing Record 32 of Set 5 | oussouye
# Processing Record 33 of Set 5 | borujan
# City not found. Skipping...
# Processing Record 34 of Set 5 | gwembe
# Processing Record 35 of Set 5 | tonantins
# Processing Record 36 of Set 5 | adrar
# Processing Record 37 of Set 5 | broken hill
# Processing Record 38 of Set 5 | maoming
# Processing Record 39 of Set 5 | rio gallegos
# Processing Record 40 of Set 5 | bosaso
# Processing Record 41 of Set 5 | domoni
# Processing Record 42 of Set 5 | chuy
# Processing Record 43 of Set 5 | vestbygda
# City not found. Skipping...
# Processing Record 44 of Set 5 | avera
# Processing Record 45 of Set 5 | pisco
# Processing Record 46 of Set 5 | burdur
# Processing Record 47 of Set 5 | mayya
# Processing Record 48 of Set 5 | volksrust
# Processing Record 49 of Set 5 | tabou
# Processing Record 50 of Set 5 | kudahuvadhoo
# Processing Record 1 of Set 6 | margate
# Processing Record 2 of Set 6 | port blair
# Processing Record 3 of Set 6 | hailar
# Processing Record 4 of Set 6 | vila velha
# Processing Record 5 of Set 6 | shingu
# Processing Record 6 of Set 6 | villazon
# Processing Record 7 of Set 6 | seaford
# Processing Record 8 of Set 6 | kaeo
# Processing Record 9 of Set 6 | leeton
# Processing Record 10 of Set 6 | chokurdakh
# Processing Record 11 of Set 6 | marienburg
# Processing Record 12 of Set 6 | bela vista
# Processing Record 13 of Set 6 | qandala
# Processing Record 14 of Set 6 | cap-aux-meules
# Processing Record 15 of Set 6 | phan thiet
# Processing Record 16 of Set 6 | sept-iles
# Processing Record 17 of Set 6 | katsuura
# Processing Record 18 of Set 6 | ponta delgada
# Processing Record 19 of Set 6 | sinnamary
# Processing Record 20 of Set 6 | deputatskiy
# Processing Record 21 of Set 6 | normandin
# Processing Record 22 of Set 6 | fortuna
# Processing Record 23 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 24 of Set 6 | san quintin
# Processing Record 25 of Set 6 | jasidih
# Processing Record 26 of Set 6 | necochea
# Processing Record 27 of Set 6 | batagay-alyta
# Processing Record 28 of Set 6 | lavrentiya
# Processing Record 29 of Set 6 | namatanai
# Processing Record 30 of Set 6 | shiyan
# Processing Record 31 of Set 6 | ambilobe
# Processing Record 32 of Set 6 | port hardy
# Processing Record 33 of Set 6 | wallacetown
# Processing Record 34 of Set 6 | narsaq
# Processing Record 35 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 6 | boddam
# Processing Record 37 of Set 6 | leeuwarden
# Processing Record 38 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 39 of Set 6 | trat
# Processing Record 40 of Set 6 | samarai
# Processing Record 41 of Set 6 | sungurlu
# Processing Record 42 of Set 6 | kruisfontein
# Processing Record 43 of Set 6 | stoyba
# City not found. Skipping...
# Processing Record 44 of Set 6 | vostok
# Processing Record 45 of Set 6 | gravdal
# Processing Record 46 of Set 6 | luanda
# Processing Record 47 of Set 6 | hobyo
# Processing Record 48 of Set 6 | tura
# Processing Record 49 of Set 6 | vila franca do campo
# Processing Record 50 of Set 6 | feijo
# Processing Record 1 of Set 7 | talnakh
# Processing Record 2 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 7 | havre-saint-pierre
# Processing Record 4 of Set 7 | grand-bourg
# Processing Record 5 of Set 7 | hualmay
# Processing Record 6 of Set 7 | ketchikan
# Processing Record 7 of Set 7 | broome
# Processing Record 8 of Set 7 | salur
# Processing Record 9 of Set 7 | guerrero negro
# Processing Record 10 of Set 7 | port-cartier
# Processing Record 11 of Set 7 | ingham
# Processing Record 12 of Set 7 | vuktyl
# Processing Record 13 of Set 7 | okha
# Processing Record 14 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 15 of Set 7 | taltal
# Processing Record 16 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 18 of Set 7 | mega
# Processing Record 19 of Set 7 | buin
# Processing Record 20 of Set 7 | lata
# Processing Record 21 of Set 7 | haapiti
# Processing Record 22 of Set 7 | virginia beach
# Processing Record 23 of Set 7 | ballina
# Processing Record 24 of Set 7 | castanos
# Processing Record 25 of Set 7 | yar-sale
# Processing Record 26 of Set 7 | la palma
# Processing Record 27 of Set 7 | puerto pinasco
# City not found. Skipping...
# Processing Record 28 of Set 7 | hengshui
# Processing Record 29 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 7 | bambous virieux
# Processing Record 31 of Set 7 | mancio lima
# Processing Record 32 of Set 7 | champasak
# Processing Record 33 of Set 7 | padang
# Processing Record 34 of Set 7 | byron bay
# Processing Record 35 of Set 7 | coos bay
# Processing Record 36 of Set 7 | ust-nera
# Processing Record 37 of Set 7 | geraldton
# Processing Record 38 of Set 7 | mackay
# Processing Record 39 of Set 7 | san cristobal
# Processing Record 40 of Set 7 | falam
# Processing Record 41 of Set 7 | marawi
# Processing Record 42 of Set 7 | yazoo city
# Processing Record 43 of Set 7 | havelock
# Processing Record 44 of Set 7 | matay
# Processing Record 45 of Set 7 | khorramabad
# Processing Record 46 of Set 7 | pribinic
# Processing Record 47 of Set 7 | amahai
# Processing Record 48 of Set 7 | kimbe
# Processing Record 49 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 7 | gifhorn
# Processing Record 1 of Set 8 | nacala
# Processing Record 2 of Set 8 | wajima
# Processing Record 3 of Set 8 | dekar
# Processing Record 4 of Set 8 | kodinsk
# Processing Record 5 of Set 8 | saint-joseph
# Processing Record 6 of Set 8 | jiuquan
# Processing Record 7 of Set 8 | krasnokholm
# Processing Record 8 of Set 8 | barentu
# Processing Record 9 of Set 8 | sento se
# City not found. Skipping...
# Processing Record 10 of Set 8 | zhanakorgan
# Processing Record 11 of Set 8 | fairbanks
# Processing Record 12 of Set 8 | burica
# City not found. Skipping...
# Processing Record 13 of Set 8 | viedma
# Processing Record 14 of Set 8 | tiarei
# Processing Record 15 of Set 8 | rovaniemi
# Processing Record 16 of Set 8 | gazli
# Processing Record 17 of Set 8 | tautira
# Processing Record 18 of Set 8 | rozivka
# Processing Record 19 of Set 8 | murray bridge
# Processing Record 20 of Set 8 | dali
# Processing Record 21 of Set 8 | zyryanka
# Processing Record 22 of Set 8 | klaksvik
# Processing Record 23 of Set 8 | aripuana
# Processing Record 24 of Set 8 | uray
# Processing Record 25 of Set 8 | luorong
# Processing Record 26 of Set 8 | sao joao da barra
# Processing Record 27 of Set 8 | buluang
# Processing Record 28 of Set 8 | severo-kurilsk
# Processing Record 29 of Set 8 | bahia honda
# Processing Record 30 of Set 8 | sobolevo
# Processing Record 31 of Set 8 | ahipara
# Processing Record 32 of Set 8 | polyarnyy
# Processing Record 33 of Set 8 | jertih
# Processing Record 34 of Set 8 | mehamn
# Processing Record 35 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 8 | maceio
# Processing Record 37 of Set 8 | batemans bay
# Processing Record 38 of Set 8 | stornoway
# Processing Record 39 of Set 8 | samsun
# Processing Record 40 of Set 8 | winnemucca
# Processing Record 41 of Set 8 | zaragoza
# Processing Record 42 of Set 8 | taut
# Processing Record 43 of Set 8 | mitsamiouli
# Processing Record 44 of Set 8 | irbit
# Processing Record 45 of Set 8 | el dorado
# Processing Record 46 of Set 8 | constitucion
# Processing Record 47 of Set 8 | san rafael
# Processing Record 48 of Set 8 | road town
# Processing Record 49 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 8 | kloulklubed
# Processing Record 1 of Set 9 | makakilo city
# Processing Record 2 of Set 9 | sarangani
# Processing Record 3 of Set 9 | kahului
# Processing Record 4 of Set 9 | chenghai
# Processing Record 5 of Set 9 | nalut
# Processing Record 6 of Set 9 | dunedin
# Processing Record 7 of Set 9 | kushima
# Processing Record 8 of Set 9 | chapais
# Processing Record 9 of Set 9 | cherskiy
# Processing Record 10 of Set 9 | hearst
# Processing Record 11 of Set 9 | nantucket
# Processing Record 12 of Set 9 | aranos
# Processing Record 13 of Set 9 | chicama
# Processing Record 14 of Set 9 | lumby
# Processing Record 15 of Set 9 | waingapu
# Processing Record 16 of Set 9 | abu kamal
# Processing Record 17 of Set 9 | duluth
# Processing Record 18 of Set 9 | bathsheba
# Processing Record 19 of Set 9 | riaba
# City not found. Skipping...
# Processing Record 20 of Set 9 | progreso
# Processing Record 21 of Set 9 | shenkursk
# Processing Record 22 of Set 9 | panjab
# Processing Record 23 of Set 9 | jumla
# Processing Record 24 of Set 9 | columbus
# Processing Record 25 of Set 9 | grand gaube
# Processing Record 26 of Set 9 | trincomalee
# Processing Record 27 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 28 of Set 9 | banda aceh
# Processing Record 29 of Set 9 | lafia
# Processing Record 30 of Set 9 | touros
# Processing Record 31 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 9 | kirensk
# Processing Record 33 of Set 9 | farafangana
# Processing Record 34 of Set 9 | sainte-rose
# Processing Record 35 of Set 9 | la ronge
# Processing Record 36 of Set 9 | bakchar
# Processing Record 37 of Set 9 | turukhansk
# Processing Record 38 of Set 9 | olinda
# Processing Record 39 of Set 9 | norman wells
# Processing Record 40 of Set 9 | tisul
# Processing Record 41 of Set 9 | tomatlan
# Processing Record 42 of Set 9 | payo
# Processing Record 43 of Set 9 | cabo san lucas
# Processing Record 44 of Set 9 | sambava
# Processing Record 45 of Set 9 | ilulissat
# Processing Record 46 of Set 9 | suzu
# City not found. Skipping...
# Processing Record 47 of Set 9 | bara
# Processing Record 48 of Set 9 | lapua
# Processing Record 49 of Set 9 | koutiala
# Processing Record 50 of Set 9 | lebowakgomo
# Processing Record 1 of Set 10 | macusani
# Processing Record 2 of Set 10 | anadyr
# Processing Record 3 of Set 10 | katiola
# Processing Record 4 of Set 10 | alice springs
# Processing Record 5 of Set 10 | kholmogory
# Processing Record 6 of Set 10 | catamarca
# Processing Record 7 of Set 10 | kampot
# Processing Record 8 of Set 10 | sal rei
# Processing Record 9 of Set 10 | nyurba
# Processing Record 10 of Set 10 | nioro
# Processing Record 11 of Set 10 | santa rosa
# Processing Record 12 of Set 10 | juba
# Processing Record 13 of Set 10 | smithers
# Processing Record 14 of Set 10 | quatre cocos
# Processing Record 15 of Set 10 | karaton
# Processing Record 16 of Set 10 | laguna
# Processing Record 17 of Set 10 | alto piquiri
# Processing Record 18 of Set 10 | waw
# Processing Record 19 of Set 10 | neijiang
# Processing Record 20 of Set 10 | morondava
# Processing Record 21 of Set 10 | luderitz
# Processing Record 22 of Set 10 | denpasar
# Processing Record 23 of Set 10 | arona
# Processing Record 24 of Set 10 | shakhtinsk
# Processing Record 25 of Set 10 | semey
# Processing Record 26 of Set 10 | srednekolymsk
# Processing Record 27 of Set 10 | gimli
# Processing Record 28 of Set 10 | gannan
# Processing Record 29 of Set 10 | plettenberg bay
# Processing Record 30 of Set 10 | taunggyi
# Processing Record 31 of Set 10 | bala
# Processing Record 32 of Set 10 | alberton
# Processing Record 33 of Set 10 | jalu
# Processing Record 34 of Set 10 | bulaevo
# Processing Record 35 of Set 10 | bodaybo
# Processing Record 36 of Set 10 | grindavik
# Processing Record 37 of Set 10 | mount gambier
# Processing Record 38 of Set 10 | negara
# Processing Record 39 of Set 10 | sharjah
# Processing Record 40 of Set 10 | teguldet
# Processing Record 41 of Set 10 | sabang
# Processing Record 42 of Set 10 | north bend
# Processing Record 43 of Set 10 | sulz
# Processing Record 44 of Set 10 | livingston
# Processing Record 45 of Set 10 | benalla
# Processing Record 46 of Set 10 | sulangan
# Processing Record 47 of Set 10 | wewak
# Processing Record 48 of Set 10 | glace bay
# Processing Record 49 of Set 10 | ca mau
# Processing Record 50 of Set 10 | lasa
# Processing Record 1 of Set 11 | yukuhashi
# Processing Record 2 of Set 11 | tulagi
# Processing Record 3 of Set 11 | saldanha
# Processing Record 4 of Set 11 | maua
# Processing Record 5 of Set 11 | port macquarie
# Processing Record 6 of Set 11 | lerwick
# Processing Record 7 of Set 11 | vangaindrano
# Processing Record 8 of Set 11 | kamskiye polyany
# Processing Record 9 of Set 11 | naze
# Processing Record 10 of Set 11 | port moresby
# Processing Record 11 of Set 11 | lima
# Processing Record 12 of Set 11 | honiara
# Processing Record 13 of Set 11 | isla vista
# Processing Record 14 of Set 11 | maturin
# Processing Record 15 of Set 11 | praia da vitoria
# Processing Record 16 of Set 11 | ban phai
# Processing Record 17 of Set 11 | fez
# Processing Record 18 of Set 11 | cooma
# Processing Record 19 of Set 11 | kuldiga
# Processing Record 20 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 21 of Set 11 | ancud
# Processing Record 22 of Set 11 | kiunga
# Processing Record 23 of Set 11 | purna
# Processing Record 24 of Set 11 | san felipe
# Processing Record 25 of Set 11 | delmas
# Processing Record 26 of Set 11 | kampen
# Processing Record 27 of Set 11 | cascavel
# Processing Record 28 of Set 11 | zakamensk
# Processing Record 29 of Set 11 | eureka
# Processing Record 30 of Set 11 | tingo maria
# Processing Record 31 of Set 11 | toora-khem
# Processing Record 32 of Set 11 | husavik
# Processing Record 33 of Set 11 | daru
# Processing Record 34 of Set 11 | qianan
# Processing Record 35 of Set 11 | constantine
# Processing Record 36 of Set 11 | pringsewu
# Processing Record 37 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 38 of Set 11 | ratnagiri
# Processing Record 39 of Set 11 | ayan
# Processing Record 40 of Set 11 | bolshaya sosnova
# Processing Record 41 of Set 11 | vestmanna
# Processing Record 42 of Set 11 | kenai
# Processing Record 43 of Set 11 | nuevo progreso
# Processing Record 44 of Set 11 | kostomuksha
# Processing Record 45 of Set 11 | bulgan
# Processing Record 46 of Set 11 | lamar
# Processing Record 47 of Set 11 | pulaski
# Processing Record 48 of Set 11 | altamira
# Processing Record 49 of Set 11 | manggar
# Processing Record 50 of Set 11 | huarmey
# Processing Record 1 of Set 12 | mayo
# Processing Record 2 of Set 12 | kohima
# Processing Record 3 of Set 12 | yialos
# City not found. Skipping...
# Processing Record 4 of Set 12 | dukat
# Processing Record 5 of Set 12 | sao miguel do araguaia
# Processing Record 6 of Set 12 | carutapera
# Processing Record 7 of Set 12 | rundu
# Processing Record 8 of Set 12 | tual
# Processing Record 9 of Set 12 | perth
# Processing Record 10 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 11 of Set 12 | waterloo
# Processing Record 12 of Set 12 | marsabit
# Processing Record 13 of Set 12 | navalmoral de la mata
# Processing Record 14 of Set 12 | trairi
# Processing Record 15 of Set 12 | poum
# Processing Record 16 of Set 12 | rocha
# Processing Record 17 of Set 12 | vryburg
# Processing Record 18 of Set 12 | asfi
# Processing Record 19 of Set 12 | anloga
# Processing Record 20 of Set 12 | lubango
# Processing Record 21 of Set 12 | gzhatsk
# City not found. Skipping...
# Processing Record 22 of Set 12 | novyy nekouz
# Processing Record 23 of Set 12 | tuatapere
# Processing Record 24 of Set 12 | hun
# Processing Record 25 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 26 of Set 12 | kafr sawm
# Processing Record 27 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 28 of Set 12 | clacton-on-sea
# Processing Record 29 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 30 of Set 12 | muskogee
# Processing Record 31 of Set 12 | pombas
# Processing Record 32 of Set 12 | moyale
# Processing Record 33 of Set 12 | kungurtug
# Processing Record 34 of Set 12 | koyilandi
# City not found. Skipping...
# Processing Record 35 of Set 12 | pallasovka
# Processing Record 36 of Set 12 | severnyy
# Processing Record 37 of Set 12 | wyndham
# Processing Record 38 of Set 12 | harper
# Processing Record 39 of Set 12 | kamenka
# Processing Record 40 of Set 12 | lyuban
# Processing Record 41 of Set 12 | tinde
# Processing Record 42 of Set 12 | usumatlan
# Processing Record 43 of Set 12 | komsomolskiy
# Processing Record 44 of Set 12 | oga
# Processing Record 45 of Set 12 | rodeo
# Processing Record 46 of Set 12 | riyadh
# Processing Record 47 of Set 12 | kintampo
# Processing Record 48 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 49 of Set 12 | santa isabel do rio negro
# Processing Record 50 of Set 12 | palmer
# Processing Record 1 of Set 13 | tatarskaya pishlya
# Processing Record 2 of Set 13 | visnes
# Processing Record 3 of Set 13 | chernyshevskiy
# Processing Record 4 of Set 13 | iquitos
# Processing Record 5 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 6 of Set 13 | lumeje
# Processing Record 7 of Set 13 | charters towers
# Processing Record 8 of Set 13 | manaus
# Processing Record 9 of Set 13 | sakakah
# Processing Record 10 of Set 13 | sungairaya
# Processing Record 11 of Set 13 | mujiayingzi
# Processing Record 12 of Set 13 | kiruna
# Processing Record 13 of Set 13 | miranda
# Processing Record 14 of Set 13 | russell
# Processing Record 15 of Set 13 | ostrovnoy
# Processing Record 16 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 18 of Set 13 | hami
# Processing Record 19 of Set 13 | sinjai
# Processing Record 20 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 21 of Set 13 | anguillara sabazia
# Processing Record 22 of Set 13 | uyuni
# Processing Record 23 of Set 13 | tarakan
# Processing Record 24 of Set 13 | beni suef
# Processing Record 25 of Set 13 | dhidhdhoo
# Processing Record 26 of Set 13 | gawler
# Processing Record 27 of Set 13 | bathurst
# Processing Record 28 of Set 13 | arman
# Processing Record 29 of Set 13 | pasni
# Processing Record 30 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 13 | rantauprapat
# Processing Record 32 of Set 13 | tete
# Processing Record 33 of Set 13 | juneau
# Processing Record 34 of Set 13 | kokoda
# Processing Record 35 of Set 13 | namwala
# Processing Record 36 of Set 13 | bafoulabe
# Processing Record 37 of Set 13 | bellevue
# Processing Record 38 of Set 13 | klyuchi
# Processing Record 39 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 13 | gizo
# Processing Record 41 of Set 13 | dharchula
# Processing Record 42 of Set 13 | lake city
# Processing Record 43 of Set 13 | bairnsdale
# Processing Record 44 of Set 13 | cuiaba
# Processing Record 45 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 46 of Set 13 | najran
# Processing Record 47 of Set 13 | thinadhoo
# Processing Record 48 of Set 13 | springbok
# Processing Record 49 of Set 13 | monteagudo
# Processing Record 50 of Set 13 | khorixas
# Processing Record 1 of Set 14 | mindelo
# Processing Record 2 of Set 14 | frontera
# Processing Record 3 of Set 14 | banyo
# Processing Record 4 of Set 14 | aswan
# Processing Record 5 of Set 14 | lorengau
# Processing Record 6 of Set 14 | santo antonio do leverger
# Processing Record 7 of Set 14 | nador
# Processing Record 8 of Set 14 | pietermaritzburg
# Processing Record 9 of Set 14 | araouane
# Processing Record 10 of Set 14 | abu samrah
# Processing Record 11 of Set 14 | rawson
# Processing Record 12 of Set 14 | warmbad
# Processing Record 13 of Set 14 | bustamante
# Processing Record 14 of Set 14 | esso
# Processing Record 15 of Set 14 | toftir
# City not found. Skipping...
# Processing Record 16 of Set 14 | gallup
# Processing Record 17 of Set 14 | qasigiannguit
# Processing Record 18 of Set 14 | kitwe
# Processing Record 19 of Set 14 | svetlogorsk
# Processing Record 20 of Set 14 | nome
# Processing Record 21 of Set 14 | esperantinopolis
# Processing Record 22 of Set 14 | basar
# Processing Record 23 of Set 14 | bogorodskoye
# Processing Record 24 of Set 14 | flin flon
# Processing Record 25 of Set 14 | bendigo
# Processing Record 26 of Set 14 | westport
# Processing Record 27 of Set 14 | doctor juan manuel frutos
# Processing Record 28 of Set 14 | mazyr
# Processing Record 29 of Set 14 | iquique
# Processing Record 30 of Set 14 | pangoa
# Processing Record 31 of Set 14 | florenville
# Processing Record 32 of Set 14 | olafsvik
# Processing Record 33 of Set 14 | high level
# Processing Record 34 of Set 14 | san policarpo
# Processing Record 35 of Set 14 | calama
# Processing Record 36 of Set 14 | baijiantan
# Processing Record 37 of Set 14 | tuggurt
# City not found. Skipping...
# Processing Record 38 of Set 14 | fayaoue
# Processing Record 39 of Set 14 | bagdarin
# Processing Record 40 of Set 14 | astana
# Processing Record 41 of Set 14 | millbrook
# Processing Record 42 of Set 14 | huambo
# Processing Record 43 of Set 14 | almaznyy
# Processing Record 44 of Set 14 | vorobyevka
# Processing Record 45 of Set 14 | brae
# Processing Record 46 of Set 14 | bharatpur
# Processing Record 47 of Set 14 | paamiut
# Processing Record 48 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 49 of Set 14 | licheng
# Processing Record 50 of Set 14 | gat
# Processing Record 1 of Set 15 | eydhafushi
# Processing Record 2 of Set 15 | cap malheureux
# Processing Record 3 of Set 15 | ocos
# Processing Record 4 of Set 15 | awbari
# Processing Record 5 of Set 15 | sur
# Processing Record 6 of Set 15 | ilovka
# Processing Record 7 of Set 15 | ponnani
# Processing Record 8 of Set 15 | yining
# Processing Record 9 of Set 15 | sweetwater
# Processing Record 10 of Set 15 | vung tau
# Processing Record 11 of Set 15 | winchester
# Processing Record 12 of Set 15 | mildura
# Processing Record 13 of Set 15 | dhuburi
# Processing Record 14 of Set 15 | elko
# Processing Record 15 of Set 15 | lebanon
# Processing Record 16 of Set 15 | tagusao
# Processing Record 17 of Set 15 | sistranda
# Processing Record 18 of Set 15 | voh
# Processing Record 19 of Set 15 | washington
# Processing Record 20 of Set 15 | bam
# Processing Record 21 of Set 15 | yagodnoye
# Processing Record 22 of Set 15 | casas grandes
# Processing Record 23 of Set 15 | preobrazheniye
# Processing Record 24 of Set 15 | vouliagmeni
# Processing Record 25 of Set 15 | elk
# Processing Record 26 of Set 15 | tarudant
# City not found. Skipping...
# Processing Record 27 of Set 15 | mahanoro
# Processing Record 28 of Set 15 | port keats
# Processing Record 29 of Set 15 | azare
# Processing Record 30 of Set 15 | parangan
# Processing Record 31 of Set 15 | leh
# Processing Record 32 of Set 15 | morros
# Processing Record 33 of Set 15 | rairangpur
# Processing Record 34 of Set 15 | xuchang
# Processing Record 35 of Set 15 | surt
# Processing Record 36 of Set 15 | makung
# City not found. Skipping...
# Processing Record 37 of Set 15 | dicabisagan
# Processing Record 38 of Set 15 | chimore
# Processing Record 39 of Set 15 | hannibal
# Processing Record 40 of Set 15 | vannes
# Processing Record 41 of Set 15 | narrabri
# Processing Record 42 of Set 15 | purpe
# Processing Record 43 of Set 15 | college
# Processing Record 44 of Set 15 | molepolole
# Processing Record 45 of Set 15 | gamboula
# Processing Record 46 of Set 15 | umm lajj
# Processing Record 47 of Set 15 | ardistan
# City not found. Skipping...
# Processing Record 48 of Set 15 | vila do maio
# Processing Record 49 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 1 of Set 16 | manhattan
# Processing Record 2 of Set 16 | sahrak
# City not found. Skipping...
# Processing Record 3 of Set 16 | shenzhen
# Processing Record 4 of Set 16 | holoby
# Processing Record 5 of Set 16 | requena
# Processing Record 6 of Set 16 | half moon bay
# Processing Record 7 of Set 16 | galesong
# Processing Record 8 of Set 16 | sume
# Processing Record 9 of Set 16 | santa cruz
# Processing Record 10 of Set 16 | coracora
# Processing Record 11 of Set 16 | halifax
# Processing Record 12 of Set 16 | colares
# Processing Record 13 of Set 16 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 16 | egersund
# Processing Record 15 of Set 16 | bur gabo
# City not found. Skipping...
# Processing Record 16 of Set 16 | garmsar
# Processing Record 17 of Set 16 | jeremie
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 698

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Saint Anthony  45.0205  -93.2180     21.90        86         100
# 1     Coahuayana  18.7333 -103.6833     74.17        87           1
# 2        Lagunas  -5.2269  -75.6753     67.73        99          97
# 3        Rikitea -23.1203 -134.9692     73.89        90         100
# 4          Pevek  69.7008  170.3133     -2.69        99          97
# 5          Libas   9.8833  125.9833     76.75        89         100
# 6   Punta Arenas -53.1500  -70.9167     46.51        76           0
# 7        Mataura -46.1927  168.8643     58.48        89          97
# 8      Jamestown  42.0970  -79.2353     32.02        77         100
# 9         Albany  42.6001  -73.9662     36.57        89          63
#
#    Wind Speed Current Description Country
# 0        9.22                snow      US
# 1        3.49           clear sky      MX
# 2        1.68     overcast clouds      PE
# 3       20.78       moderate rain      PF
# 4        5.06     overcast clouds      RU
# 5        6.24       moderate rain      PH
# 6        6.91           clear sky      CL
# 7        3.47          light rain      NZ
# 8       16.11          light snow      US
# 9        7.58       broken clouds      US

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", "Current Description" ]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Saint Anthony      US  45.0205  -93.2180     21.90        86         100
# 1       Coahuayana      MX  18.7333 -103.6833     74.17        87           1
# 2          Lagunas      PE  -5.2269  -75.6753     67.73        99          97
# 3          Rikitea      PF -23.1203 -134.9692     73.89        90         100
# 4            Pevek      RU  69.7008  170.3133     -2.69        99          97
# ..             ...     ...      ...       ...       ...       ...         ...
# 693        Halifax      CA  44.6453  -63.5724     53.69        95         100
# 694        Colares      PT  38.7992   -9.4469     66.76        96          98
# 695       Egersund      NO  58.4513    5.9997     43.38        79         100
# 696        Garmsar      IR  35.2182   52.3409     58.55        40          75
# 697        Jeremie      HT  18.6500  -74.1167     78.28        84          17
#
#      Wind Speed Current Description
# 0          9.22                snow
# 1          3.49           clear sky
# 2          1.68     overcast clouds
# 3         20.78       moderate rain
# 4          5.06     overcast clouds
# ..          ...                 ...
# 693       18.41     overcast clouds
# 694       18.01     overcast clouds
# 695       30.71     overcast clouds
# 696        4.12       broken clouds
# 697        3.58          few clouds
#
# [698 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
